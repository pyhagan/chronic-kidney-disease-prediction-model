# %% [markdown]
# # First Attempt

# %%
import pandas as pd
import seaborn as sb 
import numpy as np

# %%
data = pd.read_csv("kidney_disease_complete_2b.csv")

# %%
data.head()
# Out:
#    id  age  bp     sg  al  su     rbc        pc         pcc          ba  ...  \
# 0   0   48  80  1.020   1   0  normal    normal  notpresent  notpresent  ...
# 1   2   62  80  1.010   2   3  normal    normal  notpresent  notpresent  ...
# 2   3   48  70  1.005   4   0  normal  abnormal     present  notpresent  ...
# 3   4   51  80  1.010   2   0  normal    normal  notpresent  notpresent  ...
# 4   5   60  90  1.015   3   0  normal    normal  notpresent  notpresent  ...
#
#    pcv    wc   rc  htn   dm  cad  appet   pe  ane classification
# 0   44  7800  5.2  yes  yes   no   good   no   no            ckd
# 1   31  7500  3.7   no  yes   no   poor   no  yes            ckd
# 2   32  6700  3.9  yes   no   no   poor  yes  yes            ckd
# 3   35  7300  4.6   no   no   no   good   no   no            ckd
# 4   39  7800  4.4  yes  yes   no   good  yes   no            ckd
#
# [5 rows x 26 columns]

# %%
data.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
data.select_dtypes(include='object')
# Out:
#         rbc        pc         pcc          ba  htn   dm cad appet   pe  ane  \
# 0    normal    normal  notpresent  notpresent  yes  yes  no  good   no   no
# 1    normal    normal  notpresent  notpresent   no  yes  no  poor   no  yes
# 2    normal  abnormal     present  notpresent  yes   no  no  poor  yes  yes
# 3    normal    normal  notpresent  notpresent   no   no  no  good   no   no
# 4    normal    normal  notpresent  notpresent  yes  yes  no  good  yes   no
# ..      ...       ...         ...         ...  ...  ...  ..   ...  ...  ...
# 375  normal    normal  notpresent  notpresent   no   no  no  good   no   no
# 376  normal    normal  notpresent  notpresent   no   no  no  good   no   no
# 377  normal    normal  notpresent  notpresent   no   no  no  good   no   no
# 378  normal    normal  notpresent  notpresent   no   no  no  good   no   no
# 379  normal    normal  notpresent  notpresent   no   no  no  good   no   no
#
#     classification
# 0              ckd
# ...

# %%
import tensorflow as tf

# %%
def model():
    ''' Creates a model '''
    print(5)
